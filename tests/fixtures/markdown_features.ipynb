# %% [markdown]
# # Markdown Rendering
#
# This paragraph has **bold text**, *italic text*, `inline code`, and [a link](https://example.com).
#
# > A block quote with **emphasis**.
#
# - First item
# - Second item
#   - Nested item
#
# - [ ] Unfinished task
# - [x] Finished task
#
# | Feature | Example |
# | --- | --- |
# | Inline code | `value = 42` |
# | Emphasis | **bold** and *italic* |
#
# ```python
# def greet(name):
#     return f"Hello, {name}!"
# ```
#
# Inline math: $1 + 2 = 3$.
#
# $$
# \sum_{i=1}^{n} i = \frac{n(n+1)}{2}
# $$
#
# ## Another Heading
#
# ---
#
# Rendering should stop at the Markdown cell boundary.

# %%
# This remains a Python comment
message = "**This remains a Python string**"
print(message)

# %% [raw]
# # This raw cell is not rendered as Markdown
# **These markers remain literal.**
